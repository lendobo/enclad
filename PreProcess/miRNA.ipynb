# %%
import pandas as pd
import numpy as np

# read in .txt file as a dataframe, first line contains columns, subsequent lines contain data with gene name as index
df = pd.read_csv('/home/celeroid/Documents/CLS_MSc/Thesis/EcoCancer/hNITR/phase_1_code/data/Synapse/TCGA/TCGACRC_microarray.txt', sep='\t', index_col=0)

df.head()
# Out:
#               TCGA.AA.3966  TCGA.AA.3994  TCGA.AY.4070  TCGA.AY.4071
# A_23_P104812          0.03          0.86          0.37         0.860  \
# A_24_P227168         -0.43          0.48          1.23         0.190
# A_23_P75312           1.18          0.47         -0.22         1.240
# A_24_P70891          -0.60         -0.42         -0.44        -0.040
# A_23_P130954           NaN         -2.15         -3.12        -2.168
#
#               TCGA.A6.2670  TCGA.A6.2674  TCGA.A6.2677  TCGA.A6.2678
# A_23_P104812          0.64          0.89          0.80         1.395  \
# A_24_P227168          0.18         -0.08          0.35         0.320
# A_23_P75312          -1.25          1.20         -1.47        -1.700
# A_24_P70891           0.82          0.66          0.18        -0.220
# A_23_P130954         -3.13         -2.76         -2.09        -2.900
#
#               TCGA.A6.2683  TCGA.AA.3514  ...  TCGA.AG.3898  TCGA.AG.3901
# ...
